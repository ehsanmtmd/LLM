# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# !pip install ollama
# Out:
# Collecting ollama
#   Downloading ollama-0.4.7-py3-none-any.whl.metadata (4.7 kB)
# Collecting httpx<0.29,>=0.27 (from ollama)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting pydantic<3.0.0,>=2.9.0 (from ollama)
#   Downloading pydantic-2.10.5-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: anyio in c:\users\asus\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (4.2.0)
# Requirement already satisfied: certifi in c:\users\asus\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (2024.2.2)
# Collecting httpcore==1.* (from httpx<0.29,>=0.27->ollama)
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in c:\users\asus\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (3.4)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<0.29,>=0.27->ollama)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.9.0->ollama)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3.0.0,>=2.9.0->ollama)
#   Downloading pydantic_core-2.27.2-cp311-cp311-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-extensions>=4.12.2 (from pydantic<3.0.0,>=2.9.0->ollama)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\asus\anaconda3\lib\site-packages (from anyio->httpx<0.29,>=0.27->ollama) (1.3.0)
# Downloading ollama-0.4.7-py3-none-any.whl (13 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/73.5 kB ? eta -:--:--
#    ----- ---------------------------------- 10.2/73.5 kB ? eta -:--:--
#    ---------------------------------------- 73.5/73.5 kB 506.2 kB/s eta 0:00:00
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.6 kB ? eta -:--:--
#    ------------------------------- -------- 61.4/78.6 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 78.6/78.6 kB 1.1 MB/s eta 0:00:00
# Downloading pydantic-2.10.5-py3-none-any.whl (431 kB)
#    ---------------------------------------- 0.0/431.4 kB ? eta -:--:--
#    -------- ------------------------------- 92.2/431.4 kB 2.6 MB/s eta 0:00:01
#    -------------- ------------------------- 153.6/431.4 kB 1.8 MB/s eta 0:00:01
#    ------------------ --------------------- 204.8/431.4 kB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 389.1/431.4 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 431.4/431.4 kB 2.1 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.2-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---- ----------------------------------- 0.2/2.0 MB 4.6 MB/s eta 0:00:01
#    ------ --------------------------------- 0.3/2.0 MB 4.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.5/2.0 MB 3.5 MB/s eta 0:00:01
#    -------------- ------------------------- 0.7/2.0 MB 3.8 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.0 MB 4.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.2/2.0 MB 4.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.4/2.0 MB 4.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.5/2.0 MB 4.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.5/2.0 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 4.2 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# Installing collected packages: typing-extensions, h11, annotated-types, pydantic-core, httpcore, pydantic, httpx, ollama
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.12
#     Uninstalling pydantic-1.10.12:
#       Successfully uninstalled pydantic-1.10.12
# Successfully installed annotated-types-0.7.0 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 ollama-0.4.7 pydantic-2.10.5 pydantic-core-2.27.2 typing-extensions-4.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-cloud-auth 0.1.4 requires pydantic<2.0, but you have pydantic 2.10.5 which is incompatible.

# %%
#Test Dorna 
from ollama import chat
from ollama import ChatResponse

response: ChatResponse = chat(model='partai/dorna-llama3', messages=[
  {
    'role': 'user',
    'content': 'چرا آسمان آبیست؟?',
  },
])
print(response['message']['content'])
print(response.message.content)
# Out:
# من فکر می‌کنم دلیل این اشتباه در اینجا وجود ندارد. آسمان، به معنای گستره اتمسفری که ما در آن زندگی می‌کنیم، آب نیست زیرا هیچ نشانه ای از وجود آب در آسمان یافت نمی‌شود. ما معمولاً کلمه "آسمان" را به عنوان توصیفی برای اطرافمان استفاده می‌کنیم و نه به عنوان چیزی که دارای ویژگی های فیزیکی است مانند رنگ آبی یا سطح آب. لطفا، اگر یک دلیل علمی خاص را دنبال کنید، من سعی می کنم با شما در این مورد صحبت کنم.
# من فکر می‌کنم دلیل این اشتباه در اینجا وجود ندارد. آسمان، به معنای گستره اتمسفری که ما در آن زندگی می‌کنیم، آب نیست زیرا هیچ نشانه ای از وجود آب در آسمان یافت نمی‌شود. ما معمولاً کلمه "آسمان" را به عنوان توصیفی برای اطرافمان استفاده می‌کنیم و نه به عنوان چیزی که دارای ویژگی های فیزیکی است مانند رنگ آبی یا سطح آب. لطفا، اگر یک دلیل علمی خاص را دنبال کنید، من سعی می کنم با شما در این مورد صحبت کنم.

# %%
#Test Dorna
response: ChatResponse = chat(model='partai/dorna-llama3', messages=[
  {
    'role': 'user',
    'content': 'چرا اینترنت قطع میشه؟',
  },
])
print(response['message']['content'])
print(response.message.content)
# Out:
# یکی از دلایل متدا اینترنت قطع شدن، خرابی ارتباطات بین مرکز داده و کاربران است. ممکن است به دلیل خرابی خطوط فیبر نوری یا مشکلات در سیستم‌های شبکه ای که بین کاربران و سرورهای وب وجود دارند، اینترنت قطع شود.
#
# بسیاری از موارد دیگر که باعث می‌شوند اینترنت قطع شود، عبارتند از:
#
# * خرابی اجزای سخت‌افزار مانند روترها یا سوئچ‌های شبکه
# * مشکلات نرم‌افزاری در سیستم عامل‌های کاربران
# * حملات سایبری که به دنبال ایجاد اختلال در عملکرد شبکه هستند
# * تغییراتی در پیکربندی تنظیمات شبکه توسط ارائه دهندگان خدمات اینترنت
# * قطع و وصل شدن لاین فیبر نوری یا خطوط تلفن<|end_of_text|>
# یکی از دلایل متدا اینترنت قطع شدن، خرابی ارتباطات بین مرکز داده و کاربران است. ممکن است به دلیل خرابی خطوط فیبر نوری یا مشکلات در سیستم‌های شبکه ای که بین کاربران و سرورهای وب وجود دارند، اینترنت قطع شود.
#
# بسیاری از موارد دیگر که باعث می‌شوند اینترنت قطع شود، عبارتند از:
#
# * خرابی اجزای سخت‌افزار مانند روترها یا سوئچ‌های شبکه
# * مشکلات نرم‌افزاری در سیستم عامل‌های کاربران
# * حملات سایبری که به دنبال ایجاد اختلال در عملکرد شبکه هستند
# * تغییراتی در پیکربندی تنظیمات شبکه توسط ارائه دهندگان خدمات اینترنت
# * قطع و وصل شدن لاین فیبر نوری یا خطوط تلفن<|end_of_text|>

# %%
response['message']['content']
# Out:
# 'یکی از دلایل متدا اینترنت قطع شدن، خرابی ارتباطات بین مرکز داده و کاربران است. ممکن است به دلیل خرابی خطوط فیبر نوری یا مشکلات در سیستم\u200cهای شبکه ای که بین کاربران و سرورهای وب وجود دارند، اینترنت قطع شود.\n\nبسیاری از موارد دیگر که باعث می\u200cشوند اینترنت قطع شود، عبارتند از:\n\n* خرابی اجزای سخت\u200cافزار مانند روترها یا سوئچ\u200cهای شبکه\n* مشکلات نرم\u200cافزاری در سیستم عامل\u200cهای کاربران\n* حملات سایبری که به دنبال ایجاد اختلال در عملکرد شبکه هستند\n* تغییراتی در پیکربندی تنظیمات شبکه توسط ارائه دهندگان خدمات اینترنت\n* قطع و وصل شدن لاین فیبر نوری یا خطوط تلفن<|end_of_text|>'

# %%
# !pip install faiss-cpu sentence-transformers ollama numpy
# Out:
# Requirement already satisfied: faiss-cpu in c:\users\user\anaconda3\lib\site-packages (1.9.0.post1)
# Requirement already satisfied: sentence-transformers in c:\users\user\desktop\llm\.venv\lib\site-packages (3.4.0)
# Requirement already satisfied: ollama in c:\users\user\anaconda3\lib\site-packages (0.4.7)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from sentence-transformers) (4.48.1)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from sentence-transformers) (0.28.0)
# Requirement already satisfied: Pillow in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: httpx<0.29,>=0.27 in c:\users\user\anaconda3\lib\site-packages (from ollama) (0.27.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\user\anaconda3\lib\site-packages (from ollama) (2.10.5)
# Requirement already satisfied: anyio in c:\users\user\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (4.2.0)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (1.0.2)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (3.7)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from httpx<0.29,>=0.27->ollama) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama) (0.14.0)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.27.2)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\user\desktop\llm\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\user\desktop\llm\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\user\desktop\llm\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)

# %%
from ollama import chat
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer
import os
import re

DOCUMENT_PATHS = [
    r'C:\Users\User\Downloads\Hamrah.txt',
    r'C:\Users\User\Downloads\vape.txt',
    r'C:\Users\User\Downloads\Shah.txt',
    r'C:\Users\User\Downloads\Khalife.txt',
    r'C:\Users\User\Downloads\carbon.txt',
    r'C:\Users\User\Downloads\takapoo.txt',
    r'C:\Users\User\Downloads\mahmood.txt'

]

EMBEDDING_MODEL = 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2'
LLM_MODEL = 'partai/dorna-llama3'
CHUNK_SIZE = 1000
OVERLAP = 200
INDEX_PATH = r'C:\Users\User\Downloads\doc_index.faiss'
CHUNK_MAP_PATH = r'C:\Users\User\Downloads\chunk_map.npy'

class AdvancedRAG:
    def __init__(self):
        self.encoder = SentenceTransformer(EMBEDDING_MODEL)
        self.index = None
        self.chunk_map = []
        
    def create_index(self):
        """Create FAISS index with cosine similarity and document mapping"""
        all_chunks = []
        doc_mapping = []
        
        # Process via CHUNKING (REQ 4 RAG)
        for doc_idx, path in enumerate(DOCUMENT_PATHS):
            with open(path, 'r', encoding='utf-8') as f:
                text = re.sub(r'\s+', ' ', f.read()).strip()
                chunks = [text[i:i+CHUNK_SIZE] for i in range(0, len(text), CHUNK_SIZE - OVERLAP)]
                all_chunks.extend(chunks)
                doc_mapping.extend([doc_idx] * len(chunks))
        
        # Normalized embeddings (REQ 4 cosine similarity)
        embeddings = self.encoder.encode(all_chunks)
        faiss.normalize_L2(embeddings)  
        
        # FAISS index & Mapping
        self.index = faiss.IndexFlatIP(embeddings.shape[1])
        self.index.add(embeddings.astype(np.float32))
        self.chunk_map = np.array(doc_mapping)
        
        # Index  
        faiss.write_index(self.index, INDEX_PATH)
        # Mapping 
        np.save(CHUNK_MAP_PATH, self.chunk_map)
    
    def load_index(self):
        """LOAD EXISTING DATA"""
        self.index = faiss.read_index(INDEX_PATH)
        self.chunk_map = np.load(CHUNK_MAP_PATH, allow_pickle=True)
        
    def query(self, question, doc_index, top_k=6):
        """DOCUMENT-SPECIFIC QUERY WITH COSINE SIMILARITY """
        # Encode 
        query_embed = self.encoder.encode([question])
        # Normalize 
        faiss.normalize_L2(query_embed)
        
        distances, indices = self.index.search(query_embed.astype(np.float32), top_k*3)
    
        relevant_chunks = []
        for idx in indices[0]:
            if self.chunk_map[idx] == doc_index:
                relevant_chunks.append(idx)
            if len(relevant_chunks) >= top_k:
                break
        
        return relevant_chunks

class AnswerGenerator:
    def __init__(self, rag_system):
        self.rag = rag_system
        self.chunks = [] 
        
    def get_answer(self, question, doc_index):
        """GENERATING CONTEXT-AWARE ANSWER"""
        if not self.chunks:
            self._load_chunks()
            
        chunk_indices = self.rag.query(question, doc_index)
        context = "\n".join([self.chunks[idx] for idx in chunk_indices])
        
        prompt = f"""با استفاده از متن زیر به سوال پاسخ دهید:
{context}

اگر پاسخ در متن وجود ندارد عبارت 'پاسخی یافت نشد' را برگردانید

سوال: {question}
پاسخ:"""
        
        response = chat(model=LLM_MODEL, messages=[{'role': 'user', 'content': prompt}])
        return response['message']['content']
    
    def _load_chunks(self):
        """LOAD ALL CHUNKS(LAZY)"""
        self.chunks = []
        for path in DOCUMENT_PATHS:
            with open(path, 'r', encoding='utf-8') as f:
                text = re.sub(r'\s+', ' ', f.read()).strip()
                self.chunks.extend([text[i:i+CHUNK_SIZE] for i in range(0, len(text), CHUNK_SIZE - OVERLAP)])

# MAIN EXE
if __name__ == "__main__":
    rag = AdvancedRAG()
    
    if not os.path.exists(INDEX_PATH):
        print("Building optimized index...")
        rag.create_index()
    else:
        print("Loading existing index...")
        rag.load_index()
    
    generator = AnswerGenerator(rag)
    
    queries = [
        ("چرا اینترنت همراه اول گوشی وصل نمیشود؟", 0),
        ("چطوری ویپ مورد نظرمو پیدا کنم؟", 1),
        ("شاه عباس که بود؟", 2),
        ("خلیفه سلطان که بود و چه کرد؟", 3),
        ("کربن اکتیو و کربن بلک چه هستند و چه تفاوتی دارند و برای چه استفاده میشن؟", 4),
        ("شرکت تکاپو صنعت نامی چه محصولاتی ارایه میدهد؟ چه چیزی این شرکت را منحصر به فرد میسازد؟ سهام این شرکت صعودی است یا نزولی؟", 5),
        ("سید محمود خلیفه سلطانی کیست؟", 6)

    ]
    
    with open(r'C:\Users\User\Downloads\representation.txt', 'w', encoding='utf-8') as f:
        for q_idx, (query, doc_idx) in enumerate(queries):
            answer = generator.get_answer(query, doc_idx)
            f.write(f"سوال {q_idx+1} ({doc_idx+1}):\n{query}\n\nپاسخ:\n{answer}\n\n{'='*50}\n\n")
            print(f"پردازش سوال {q_idx+1}/{len(queries)} تکمیل شد")

print("تمامی سوالات با موفقیت پردازش شدند!")
# Out:
# Loading existing index...
# 824
# پردازش سوال 1/7 تکمیل شد
# 679
# پردازش سوال 2/7 تکمیل شد
# 218
# پردازش سوال 3/7 تکمیل شد
# 738
# پردازش سوال 4/7 تکمیل شد
# 933
# پردازش سوال 5/7 تکمیل شد
# 1234
# پردازش سوال 6/7 تکمیل شد
# 117
# پردازش سوال 7/7 تکمیل شد
# تمامی سوالات با موفقیت پردازش شدند!

# %%
# !pip install langchain chromadb sentence-transformers ollama
# Out:
# Requirement already satisfied: langchain in c:\users\user\desktop\llm\.venv\lib\site-packages (0.3.17)
# Collecting chromadb
#   Using cached chromadb-0.6.3-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: sentence-transformers in c:\users\user\desktop\llm\.venv\lib\site-packages (3.4.0)
# Requirement already satisfied: ollama in c:\users\user\anaconda3\lib\site-packages (0.4.7)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\user\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\user\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\user\anaconda3\lib\site-packages (from langchain) (3.10.5)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.33 in c:\users\user\desktop\llm\.venv\lib\site-packages (from langchain) (0.3.33)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\user\desktop\llm\.venv\lib\site-packages (from langchain) (0.3.5)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\user\desktop\llm\.venv\lib\site-packages (from langchain) (0.3.3)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\user\anaconda3\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\user\anaconda3\lib\site-packages (from langchain) (2.10.5)
# Requirement already satisfied: requests<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\user\anaconda3\lib\site-packages (from langchain) (8.2.3)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting fastapi>=0.95.2 (from chromadb)
#   Using cached fastapi-0.115.7-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting posthog>=2.4.0 (from chromadb)
#   Using cached posthog-3.11.0-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.20.1-cp312-cp312-win_amd64.whl.metadata (4.7 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.29.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Using cached opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.29.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\user\desktop\llm\.venv\lib\site-packages (from chromadb) (0.21.0)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Using cached grpcio-1.70.0-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.2.1-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-32.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-5.1.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\user\desktop\llm\.venv\lib\site-packages (from chromadb) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from sentence-transformers) (4.48.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from sentence-transformers) (0.28.0)
# Requirement already satisfied: Pillow in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.11.0)
# Requirement already satisfied: packaging>=19.1 in c:\users\user\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi>=0.95.2->chromadb)
#   Using cached starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: anyio in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.6.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Using cached google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.33->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-25.1.24-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: protobuf in c:\users\user\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Requirement already satisfied: sympy in c:\users\user\desktop\llm\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\user\desktop\llm\.venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached googleapis_common_protos-1.66.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.29.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.29.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.29.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Using cached protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting opentelemetry-instrumentation-asgi==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation-0.50b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-util-http==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_util_http-0.50b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\user\desktop\llm\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\user\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached watchfiles-1.0.4-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached websockets-14.2-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.33->langchain) (2.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\user\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Using cached chromadb-0.6.3-py3-none-any.whl (611 kB)
# Using cached bcrypt-4.2.1-cp39-abi3-win_amd64.whl (153 kB)
# Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Using cached fastapi-0.115.7-py3-none-any.whl (94 kB)
# Using cached grpcio-1.70.0-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached kubernetes-32.0.0-py2.py3-none-any.whl (2.0 MB)
# Using cached mmh3-5.1.0-cp312-cp312-win_amd64.whl (41 kB)
# Using cached onnxruntime-1.20.1-cp312-cp312-win_amd64.whl (11.3 MB)
# Using cached opentelemetry_api-1.29.0-py3-none-any.whl (64 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.29.0-py3-none-any.whl (55 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl (12 kB)
# Using cached opentelemetry_instrumentation-0.50b0-py3-none-any.whl (30 kB)
# Using cached opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl (16 kB)
# Using cached opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl (166 kB)
# Using cached opentelemetry_util_http-0.50b0-py3-none-any.whl (6.9 kB)
# Using cached opentelemetry_sdk-1.29.0-py3-none-any.whl (118 kB)
# Using cached posthog-3.11.0-py2.py3-none-any.whl (72 kB)
# Using cached uvicorn-0.34.0-py3-none-any.whl (62 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached durationpy-0.9-py3-none-any.whl (3.5 kB)
# Using cached google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
# Using cached googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
# Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl (88 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached protobuf-5.29.3-cp310-abi3-win_amd64.whl (434 kB)
# Using cached starlette-0.45.3-py3-none-any.whl (71 kB)
# Using cached watchfiles-1.0.4-cp312-cp312-win_amd64.whl (285 kB)
# Using cached websockets-14.2-cp312-cp312-win_amd64.whl (164 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-25.1.24-py2.py3-none-any.whl (30 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Building wheels for collected packages: chroma-hnswlib
#   Building wheel for chroma-hnswlib (pyproject.toml): started
#   Building wheel for chroma-hnswlib (pyproject.toml): finished with status 'error'
# Failed to build chroma-hnswlib
#   error: subprocess-exited-with-error
#
#   Building wheel for chroma-hnswlib (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [5 lines of output]
#   running bdist_wheel
#   running build
#   running build_ext
#   building 'hnswlib' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for chroma-hnswlib
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (chroma-hnswlib)

# %%
# !pip install -U langchain-community
# Out:
# Requirement already satisfied: langchain-community in c:\users\user\desktop\llm\.venv\lib\site-packages (0.3.16)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\user\anaconda3\lib\site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\user\anaconda3\lib\site-packages (from langchain-community) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\user\anaconda3\lib\site-packages (from langchain-community) (3.10.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\user\desktop\llm\.venv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.16 in c:\users\user\desktop\llm\.venv\lib\site-packages (from langchain-community) (0.3.17)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.32 in c:\users\user\desktop\llm\.venv\lib\site-packages (from langchain-community) (0.3.33)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\user\desktop\llm\.venv\lib\site-packages (from langchain-community) (0.3.3)
# Requirement already satisfied: numpy<3,>=1.26.2 in c:\users\user\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: requests<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.11.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in c:\users\user\desktop\llm\.venv\lib\site-packages (from langchain<0.4.0,>=0.3.16->langchain-community) (0.3.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\user\anaconda3\lib\site-packages (from langchain<0.4.0,>=0.3.16->langchain-community) (2.10.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.32->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.32->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<0.4.0,>=0.3.32->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\user\desktop\llm\.venv\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2->langchain-community) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.32->langchain-community) (2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.16->langchain-community) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.16->langchain-community) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings import SentenceTransformerEmbeddings
from langchain.schema import Document
from ollama import chat
import os
import re

DOCUMENT_PATHS = [
    r'C:\Users\User\Downloads\Hamrah.txt',
    r'C:\Users\User\Downloads\vape.txt',
    r'C:\Users\User\Downloads\Shah.txt',
    r'C:\Users\User\Downloads\Khalife.txt',
    r'C:\Users\User\Downloads\carbon.txt',
    r'C:\Users\User\Downloads\takapoo.txt'
    r'C:\Users\User\Downloads\mahmood.txt'

]

EMBEDDING_MODEL = 'sentence-transformers/paraphrase-multilingual-mpnet-base-v2'
LLM_MODEL = 'partai/dorna-llama3'
CHUNK_SIZE = 1000
OVERLAP = 200
CHROMA_PERSIST_DIR = r'C:\Users\User\Downloads\chroma_db'

class ChromaRAGSystem:
    def __init__(self):
        # Init embedding model
        self.embeddings = SentenceTransformerEmbeddings(model_name=EMBEDDING_MODEL)
        # Vector store instance
        self.vector_db = None
        
    def build_vector_store(self):
        """Process documents and create Chroma vector store"""
        all_docs = []
        

        for doc_idx, path in enumerate(DOCUMENT_PATHS):
            with open(path, 'r', encoding='utf-8') as f:
                text = re.sub(r'\s+', ' ', f.read()).strip()
                # sliding window chunking
                chunks = [
                    text[i:i+CHUNK_SIZE] 
                    for i in range(0, len(text), CHUNK_SIZE - OVERLAP)
                ]
                # LangChain documents with metadata
                for chunk in chunks:
                    all_docs.append(Document(
                        page_content=chunk,
                        metadata={"source_doc": doc_idx}
                    ))
        
        # Chroma vector store
        self.vector_db = Chroma.from_documents(
            documents=all_docs,
            embedding=self.embeddings,
            persist_directory=CHROMA_PERSIST_DIR
        )
        self.vector_db.persist()
        
    def load_vector_store(self):
        """Load existing Chroma vector store"""
        self.vector_db = Chroma(
            persist_directory=CHROMA_PERSIST_DIR,
            embedding_function=self.embeddings
        )
        
    def document_query(self, query, doc_index, top_k=6):
        """Retrieve context from specific document"""
        # Chroma metadata filtering
        results = self.vector_db.similarity_search(
            query=query,
            k=top_k,
            filter={"source_doc": doc_index}
        )
        return [doc.page_content for doc in results]

class AnswerGenerator:
    def __init__(self, rag_system):
        self.rag = rag_system
        
    def generate_response(self, question, doc_index):
        """Generate context-aware answer using LLM"""
        # Retrieve relevant context
        context_chunks = self.rag.document_query(question, doc_index)
        context = "\n".join(context_chunks)
        
        prompt = f"""با استفاده از متن زیر به سوال پاسخ دهید:
{context}

اگر پاسخ در متن وجود ندارد عبارت 'پاسخی یافت نشد' را برگردانید

سوال: {question}
پاسخ:"""
        
        response = chat(model=LLM_MODEL, messages=[{'role': 'user', 'content': prompt}])
        return response['message']['content']

if __name__ == "__main__":
    rag_system = ChromaRAGSystem()
    
    # Init vector store
    if not os.path.exists(CHROMA_PERSIST_DIR):
        print("Creating new vector store...")
        rag_system.build_vector_store()
    else:
        print("Loading existing vector store...")
        rag_system.load_vector_store()
    
    # Init answer generator
    answer_engine = AnswerGenerator(rag_system)

    queries = [
        ("چرا اینترنت همراه اول گوشی وصل نمیشود؟", 0),
        ("چطوری ویپ مورد نظرمو پیدا کنم؟", 1),
        ("شاه عباس که بود؟", 2),
        ("خلیفه سلطان که بود و چه کرد؟", 3),
        ("کربن اکتیو و کربن بلک چه هستند و چه تفاوتی دارند و برای چه استفاده میشن؟", 4),
        ("شرکت تکاپو صنعت نامی چه محصولاتی ارایه میدهد؟ چه چیزی این شرکت را منحصر به فرد میسازد؟ سهام این شرکت صعودی است یا نزولی؟", 5),
        ("شرکت تکاپو صنعت نامی چه محصولاتی ارایه میدهد؟ چه چیزی این شرکت را منحصر به فرد میسازد؟ سهام این شرکت صعودی است یا نزولی؟", 6)

    ]
    
    with open(r'C:\Users\User\Downloads\representation2.txt', 'w', encoding='utf-8') as output_file:
        for q_num, (query, doc_idx) in enumerate(queries):
            answer = answer_engine.generate_response(query, doc_idx)
            output_file.write(f"سوال {q_num+1} ({doc_idx+1}):\n{query}\n\nپاسخ:\n{answer}\n\n{'='*50}\n\n")
            print(f"پردازش سوال {q_num+1}/{len(queries)} تکمیل شد")

print("تمامی سوالات با موفقیت پردازش شدند!")
# Out:
# Creating new vector store...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\Desktop\LLM\.venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:83, in Chroma.__init__(self, collection_name, embedding_function, persist_directory, client_settings, collection_metadata, client, relevance_score_fn)
#      82 try:
# ---> 83     import chromadb
#      84     import chromadb.config
#
# ModuleNotFoundError: No module named 'chromadb'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[29], line 102
#     100 if not os.path.exists(CHROMA_PERSIST_DIR):
#     101     print("Creating new vector store...")
# --> 102     rag_system.build_vector_store()
#     103 else:
#     104     print("Loading existing vector store...")
#
# Cell In[29], line 51, in ChromaRAGSystem.build_vector_store(self)
#      45             all_docs.append(Document(
#      46                 page_content=chunk,
#      47                 metadata={"source_doc": doc_idx}
#      48             ))
#      50 # Chroma vector store
# ---> 51 self.vector_db = Chroma.from_documents(
#      52     documents=all_docs,
#      53     embedding=self.embeddings,
#      54     persist_directory=CHROMA_PERSIST_DIR
#      55 )
#      56 self.vector_db.persist()
#
# File ~\Desktop\LLM\.venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:887, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     885 texts = [doc.page_content for doc in documents]
#     886 metadatas = [doc.metadata for doc in documents]
# --> 887 return cls.from_texts(
#     888     texts=texts,
#     889     embedding=embedding,
#     890     metadatas=metadatas,
#     891     ids=ids,
#     892     collection_name=collection_name,
#     893     persist_directory=persist_directory,
#     894     client_settings=client_settings,
#     895     client=client,
#     896     collection_metadata=collection_metadata,
#     897     **kwargs,
#     898 )
#
# File ~\Desktop\LLM\.venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:817, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     784 @classmethod
#     785 def from_texts(
#     786     cls: Type[Chroma],
#    (...)
#     796     **kwargs: Any,
#     797 ) -> Chroma:
#     798     """Create a Chroma vectorstore from a raw documents.
#     799
#     800     If a persist_directory is specified, the collection will be persisted there.
#    (...)
#     815         Chroma: Chroma vectorstore.
#     816     """
# --> 817     chroma_collection = cls(
#     818         collection_name=collection_name,
#     819         embedding_function=embedding,
#     820         persist_directory=persist_directory,
#     821         client_settings=client_settings,
#     822         client=client,
#     823         collection_metadata=collection_metadata,
#     824         **kwargs,
#     825     )
#     826     if ids is None:
#     827         ids = [str(uuid.uuid4()) for _ in texts]
#
# File ~\Desktop\LLM\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:214, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     212     warned = True
#     213     emit_warning()
# --> 214 return wrapped(self, *args, **kwargs)
#
# File ~\Desktop\LLM\.venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:86, in Chroma.__init__(self, collection_name, embedding_function, persist_directory, client_settings, collection_metadata, client, relevance_score_fn)
#      84     import chromadb.config
#      85 except ImportError:
# ---> 86     raise ImportError(
#      87         "Could not import chromadb python package. "
#      88         "Please install it with `pip install chromadb`."
#      89     )
#      91 if client is not None:
#      92     self._client_settings = client_settings
#
# ImportError: Could not import chromadb python package. Please install it with `pip install chromadb`.

# %%
# %pip install chromadb
# Out:
# Collecting chromadbNote: you may need to restart the kernel to use updated packages.
#
#   Using cached chromadb-0.6.3-py3-none-any.whl.metadata (6.8 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (2.10.5)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Using cached chroma_hnswlib-0.7.6.tar.gz (32 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting fastapi>=0.95.2 (from chromadb)
#   Using cached fastapi-0.115.7-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb)
#   Using cached posthog-3.11.0-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.20.1-cp312-cp312-win_amd64.whl.metadata (4.7 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from chromadb) (1.29.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Using cached opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\user\desktop\llm\.venv\lib\site-packages (from chromadb) (0.21.0)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\user\desktop\llm\.venv\lib\site-packages (from chromadb) (6.5.2)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Using cached grpcio-1.70.0-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.2.1-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-32.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-5.1.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\user\desktop\llm\.venv\lib\site-packages (from chromadb) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\user\anaconda3\lib\site-packages (from chromadb) (13.7.1)
# Requirement already satisfied: packaging>=19.1 in c:\users\user\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi>=0.95.2->chromadb)
#   Using cached starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: anyio in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.2.0)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.2)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Using cached google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\user\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-25.1.24-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: protobuf in c:\users\user\desktop\llm\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: sympy in c:\users\user\desktop\llm\.venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\user\desktop\llm\.venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached googleapis_common_protos-1.66.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.29.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.29.0)
# Collecting opentelemetry-instrumentation-asgi==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation-0.50b0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Collecting opentelemetry-util-http==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_util_http-0.50b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic>=1.9->chromadb) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\user\desktop\llm\.venv\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.28.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\user\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\user\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached watchfiles-1.0.4-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached websockets-14.2-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\user\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Using cached chromadb-0.6.3-py3-none-any.whl (611 kB)
# Using cached bcrypt-4.2.1-cp39-abi3-win_amd64.whl (153 kB)
# Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Using cached fastapi-0.115.7-py3-none-any.whl (94 kB)
# Using cached grpcio-1.70.0-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached kubernetes-32.0.0-py2.py3-none-any.whl (2.0 MB)
# Using cached mmh3-5.1.0-cp312-cp312-win_amd64.whl (41 kB)
# Using cached onnxruntime-1.20.1-cp312-cp312-win_amd64.whl (11.3 MB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl (12 kB)
# Using cached opentelemetry_instrumentation-0.50b0-py3-none-any.whl (30 kB)
# Using cached opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl (16 kB)
# Using cached opentelemetry_util_http-0.50b0-py3-none-any.whl (6.9 kB)
# Using cached posthog-3.11.0-py2.py3-none-any.whl (72 kB)
# Using cached uvicorn-0.34.0-py3-none-any.whl (62 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached durationpy-0.9-py3-none-any.whl (3.5 kB)
# Using cached google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
# Using cached googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
# Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl (88 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached starlette-0.45.3-py3-none-any.whl (71 kB)
# Using cached watchfiles-1.0.4-cp312-cp312-win_amd64.whl (285 kB)
# Using cached websockets-14.2-cp312-cp312-win_amd64.whl (164 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-25.1.24-py2.py3-none-any.whl (30 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Building wheels for collected packages: chroma-hnswlib
#   Building wheel for chroma-hnswlib (pyproject.toml): started
#   Building wheel for chroma-hnswlib (pyproject.toml): finished with status 'error'
# Failed to build chroma-hnswlib
#   error: subprocess-exited-with-error
#
#   Building wheel for chroma-hnswlib (pyproject.toml) did not run successfully.
#   exit code: 1
#
#   [5 lines of output]
#   running bdist_wheel
#   running build
#   running build_ext
#   building 'hnswlib' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for chroma-hnswlib
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (chroma-hnswlib)

# %%
# !pip install llama-index-core llama-index-embeddings-huggingface llama-index-llms-openai sentence-transformers
# Out:
# Requirement already satisfied: llama-index-core in c:\users\user\desktop\llm\.venv\lib\site-packages (0.12.14)
# Requirement already satisfied: llama-index-embeddings-huggingface in c:\users\user\desktop\llm\.venv\lib\site-packages (0.5.1)
# Collecting llama-index-llms-openai
#   Downloading llama_index_llms_openai-0.3.14-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: sentence-transformers in c:\users\user\desktop\llm\.venv\lib\site-packages (3.4.0)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (3.10.5)
# Requirement already satisfied: dataclasses-json in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (2024.6.1)
# Requirement already satisfied: httpx in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (3.3)
# Requirement already satisfied: nltk>3.8.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (3.9.1)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (10.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (2.10.5)
# Requirement already satisfied: requests>=2.31.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.19.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.28.0)
# Collecting openai<2.0.0,>=1.58.1 (from llama-index-llms-openai)
#   Downloading openai-1.60.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from sentence-transformers) (4.48.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.11.0)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.13.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.1)
# Requirement already satisfied: click in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core) (8.1.7)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core) (2024.9.11)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\anaconda3\lib\site-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai) (1.9.0)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.58.1->llama-index-llms-openai)
#   Downloading jiter-0.8.2-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from openai<2.0.0,>=1.58.1->llama-index-llms-openai) (1.3.0)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (1.0.2)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (3.0.1)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\user\desktop\llm\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core) (0.4.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\user\desktop\llm\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\user\desktop\llm\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from dataclasses-json->llama-index-core) (3.26.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Downloading llama_index_llms_openai-0.3.14-py3-none-any.whl (14 kB)
# Downloading openai-1.60.2-py3-none-any.whl (456 kB)
# Downloading jiter-0.8.2-cp312-cp312-win_amd64.whl (204 kB)
# Installing collected packages: jiter, openai, llama-index-llms-openai
# Successfully installed jiter-0.8.2 llama-index-llms-openai-0.3.14 openai-1.60.2

# %%
# !pip install llama-index-core llama-index-embeddings-huggingface llama-index-llms-ollama sentence-transformers
# Out:
# Requirement already satisfied: llama-index-core in c:\users\user\desktop\llm\.venv\lib\site-packages (0.12.14)
# Requirement already satisfied: llama-index-embeddings-huggingface in c:\users\user\desktop\llm\.venv\lib\site-packages (0.5.1)
# Requirement already satisfied: llama-index-llms-ollama in c:\users\user\desktop\llm\.venv\lib\site-packages (0.5.0)
# Requirement already satisfied: sentence-transformers in c:\users\user\desktop\llm\.venv\lib\site-packages (3.4.0)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (3.10.5)
# Requirement already satisfied: dataclasses-json in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (2024.6.1)
# Requirement already satisfied: httpx in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (3.3)
# Requirement already satisfied: nltk>3.8.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (3.9.1)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (10.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (2.10.5)
# Requirement already satisfied: requests>=2.31.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.19.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.28.0)
# Requirement already satisfied: ollama>=0.4.3 in c:\users\user\anaconda3\lib\site-packages (from llama-index-llms-ollama) (0.4.7)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from sentence-transformers) (4.48.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.11.0)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.13.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.1)
# Requirement already satisfied: click in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core) (8.1.7)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core) (2024.9.11)
# Requirement already satisfied: anyio in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (4.2.0)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (1.0.2)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (3.7)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (3.0.1)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\user\desktop\llm\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core) (0.4.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\user\desktop\llm\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\user\desktop\llm\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from dataclasses-json->llama-index-core) (3.26.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)

# %%
# !pip install llama-index-readers-file
# Out:
# Collecting llama-index-readers-file
#   Downloading llama_index_readers_file-0.4.4-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\user\anaconda3\lib\site-packages (from llama-index-readers-file) (4.12.3)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-readers-file) (0.12.14)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (from llama-index-readers-file) (2.2.2)
# Collecting pypdf<6.0.0,>=5.1.0 (from llama-index-readers-file)
#   Downloading pypdf-5.2.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file) (2.5)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.10.5)
# Requirement already satisfied: dataclasses-json in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2024.6.1)
# Requirement already satisfied: httpx in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.3)
# Requirement already satisfied: nltk>3.8.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.9.1)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (10.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.10.5)
# Requirement already satisfied: requests>=2.31.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\user\anaconda3\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas->llama-index-readers-file) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas->llama-index-readers-file) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas->llama-index-readers-file) (2023.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.11.0)
# Requirement already satisfied: click in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (8.1.7)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2024.9.11)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.27.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.0.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.26.0)
# Requirement already satisfied: anyio in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in c:\users\user\anaconda3\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (24.1)
# Downloading llama_index_readers_file-0.4.4-py3-none-any.whl (39 kB)
# Downloading pypdf-5.2.0-py3-none-any.whl (298 kB)
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Installing collected packages: striprtf, pypdf, llama-index-readers-file
# Successfully installed llama-index-readers-file-0.4.4 pypdf-5.2.0 striprtf-0.0.26

# %%
# !pip install llama-index-core llama-index-llms-ollama llama-index-embeddings-huggingface
# Out:
# Requirement already satisfied: llama-index-core in c:\users\user\desktop\llm\.venv\lib\site-packages (0.12.14)
# Requirement already satisfied: llama-index-llms-ollama in c:\users\user\desktop\llm\.venv\lib\site-packages (0.5.0)
# Requirement already satisfied: llama-index-embeddings-huggingface in c:\users\user\desktop\llm\.venv\lib\site-packages (0.5.1)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (3.10.5)
# Requirement already satisfied: dataclasses-json in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (2024.6.1)
# Requirement already satisfied: httpx in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (3.3)
# Requirement already satisfied: nltk>3.8.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (3.9.1)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (10.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (2.10.5)
# Requirement already satisfied: requests>=2.31.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (1.14.1)
# Requirement already satisfied: ollama>=0.4.3 in c:\users\user\anaconda3\lib\site-packages (from llama-index-llms-ollama) (0.4.7)
# Requirement already satisfied: huggingface-hub>=0.19.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.28.0)
# Requirement already satisfied: sentence-transformers>=2.6.1 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-embeddings-huggingface) (3.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.11.0)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.13.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.1)
# Requirement already satisfied: click in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core) (8.1.7)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core) (2024.9.11)
# Requirement already satisfied: anyio in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (4.2.0)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (1.0.2)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (3.7)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core) (2.2.3)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.48.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.5.1)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (3.0.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from dataclasses-json->llama-index-core) (3.26.0)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\user\desktop\llm\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\user\desktop\llm\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\user\desktop\llm\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.1.3)

# %%
# !pip install llama-index-core llama-index-llms-ollama llama-index-embeddings-huggingface --upgrade
# Out:
# Requirement already satisfied: llama-index-core in c:\users\user\desktop\llm\.venv\lib\site-packages (0.12.14)
# Requirement already satisfied: llama-index-llms-ollama in c:\users\user\desktop\llm\.venv\lib\site-packages (0.5.0)
# Requirement already satisfied: llama-index-embeddings-huggingface in c:\users\user\desktop\llm\.venv\lib\site-packages (0.5.1)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (3.10.5)
# Requirement already satisfied: dataclasses-json in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (1.2.18)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (2024.6.1)
# Requirement already satisfied: httpx in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (3.3)
# Requirement already satisfied: nltk>3.8.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (3.9.1)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (10.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (2.10.5)
# Requirement already satisfied: requests>=2.31.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\user\anaconda3\lib\site-packages (from llama-index-core) (1.14.1)
# Requirement already satisfied: ollama>=0.4.3 in c:\users\user\anaconda3\lib\site-packages (from llama-index-llms-ollama) (0.4.7)
# Requirement already satisfied: huggingface-hub>=0.19.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.28.0)
# Requirement already satisfied: sentence-transformers>=2.6.1 in c:\users\user\desktop\llm\.venv\lib\site-packages (from llama-index-embeddings-huggingface) (3.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.11.0)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.13.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\user\anaconda3\lib\site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.1)
# Requirement already satisfied: click in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core) (8.1.7)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\lib\site-packages (from nltk>3.8.1->llama-index-core) (2024.9.11)
# Requirement already satisfied: anyio in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (4.2.0)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (1.0.2)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (3.7)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from httpx->llama-index-core) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic>=2.8.0->llama-index-core) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.31.0->llama-index-core) (2.2.3)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.48.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.5.1)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (3.0.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\user\desktop\llm\.venv\lib\site-packages (from dataclasses-json->llama-index-core) (3.26.0)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\user\desktop\llm\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\user\desktop\llm\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\user\desktop\llm\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.1.3)

# %%
# !pip install neo4j
# Out:
# Collecting neo4j
#   Downloading neo4j-5.27.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: pytz in c:\users\user\anaconda3\lib\site-packages (from neo4j) (2024.1)
# Downloading neo4j-5.27.0-py3-none-any.whl (301 kB)
# Installing collected packages: neo4j
# Successfully installed neo4j-5.27.0

# %%
# !pip install trulens-eval --upgrade
# Out:
# Collecting trulens-eval
#   Downloading trulens_eval-1.3.3-py3-none-any.whl.metadata (1.1 kB)
# Collecting trulens-core<2.0.0,>=1.0.0 (from trulens-eval)
#   Downloading trulens_core-1.3.3-py3-none-any.whl.metadata (1.7 kB)
# Collecting trulens-dashboard<2.0.0,>=1.0.0 (from trulens-eval)
#   Downloading trulens_dashboard-1.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting trulens-feedback<2.0.0,>=1.0.0 (from trulens-eval)
#   Downloading trulens_feedback-1.3.3-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic<2.0.0,>=1.8.1 in c:\users\user\anaconda3\lib\site-packages (from trulens-core<2.0.0,>=1.0.0->trulens-eval) (1.13.3)
# Requirement already satisfied: dill>=0.3.8 in c:\users\user\anaconda3\lib\site-packages (from trulens-core<2.0.0,>=1.0.0->trulens-eval) (0.3.8)
# Collecting importlib-resources<7.0,>=6.0 (from trulens-core<2.0.0,>=1.0.0->trulens-eval)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting munch<3.0,>=2.5 (from trulens-core<2.0.0,>=1.0.0->trulens-eval)
#   Downloading munch-2.5.0-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nest-asyncio<2.0,>=1.5 in c:\users\user\anaconda3\lib\site-packages (from trulens-core<2.0.0,>=1.0.0->trulens-eval) (1.6.0)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\user\anaconda3\lib\site-packages (from trulens-core<2.0.0,>=1.0.0->trulens-eval) (1.26.4)
# Collecting opentelemetry-api<2.0.0,>=1.0.0 (from trulens-core<2.0.0,>=1.0.0->trulens-eval)
#   Using cached opentelemetry_api-1.29.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-proto<2.0.0,>=1.0.0 (from trulens-core<2.0.0,>=1.0.0->trulens-eval)
#   Using cached opentelemetry_proto-1.29.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<2.0.0,>=1.0.0 (from trulens-core<2.0.0,>=1.0.0->trulens-eval)
#   Using cached opentelemetry_sdk-1.29.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging>=23.0 in c:\users\user\anaconda3\lib\site-packages (from trulens-core<2.0.0,>=1.0.0->trulens-eval) (24.1)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from trulens-core<2.0.0,>=1.0.0->trulens-eval) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in c:\users\user\anaconda3\lib\site-packages (from trulens-core<2.0.0,>=1.0.0->trulens-eval) (2.10.5)
# Requirement already satisfied: python-dotenv<2.0,>=0.21 in c:\users\user\anaconda3\lib\site-packages (from trulens-core<2.0.0,>=1.0.0->trulens-eval) (0.21.0)
# Requirement already satisfied: requests<3.0,>=2.31 in c:\users\user\anaconda3\lib\site-packages (from trulens-core<2.0.0,>=1.0.0->trulens-eval) (2.32.3)
# Requirement already satisfied: rich<14.0,>=13.6 in c:\users\user\anaconda3\lib\site-packages (from trulens-core<2.0.0,>=1.0.0->trulens-eval) (13.7.1)
# Requirement already satisfied: sqlalchemy<3.0,>=2.0 in c:\users\user\anaconda3\lib\site-packages (from trulens-core<2.0.0,>=1.0.0->trulens-eval) (2.0.34)
# Collecting trulens-otel-semconv<2.0.0,>=1.0.0 (from trulens-core<2.0.0,>=1.0.0->trulens-eval)
#   Downloading trulens_otel_semconv-1.3.3-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: typing_extensions<5.0,>=4.9 in c:\users\user\anaconda3\lib\site-packages (from trulens-core<2.0.0,>=1.0.0->trulens-eval) (4.12.2)
# Requirement already satisfied: ipywidgets>=7.1.2 in c:\users\user\anaconda3\lib\site-packages (from trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (7.8.1)
# Requirement already satisfied: jupyter<2,>=1 in c:\users\user\anaconda3\lib\site-packages (from trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (1.0.0)
# Requirement already satisfied: plotly<6.0.0,>=5.22.0 in c:\users\user\anaconda3\lib\site-packages (from trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (5.24.1)
# Requirement already satisfied: psutil<6.0,>=5.9 in c:\users\user\anaconda3\lib\site-packages (from trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (5.9.0)
# Requirement already satisfied: streamlit<2.0,>=1.35 in c:\users\user\anaconda3\lib\site-packages (from trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (1.37.1)
# Requirement already satisfied: traitlets<6.0.0,>=5.0.5 in c:\users\user\anaconda3\lib\site-packages (from trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (5.14.3)
# Requirement already satisfied: nltk<4.0.0,>=3.9.1 in c:\users\user\anaconda3\lib\site-packages (from trulens-feedback<2.0.0,>=1.0.0->trulens-eval) (3.9.1)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.3.0 in c:\users\user\anaconda3\lib\site-packages (from trulens-feedback<2.0.0,>=1.0.0->trulens-eval) (1.5.1)
# Requirement already satisfied: scipy>=1.11.1 in c:\users\user\anaconda3\lib\site-packages (from trulens-feedback<2.0.0,>=1.0.0->trulens-eval) (1.13.1)
# Requirement already satisfied: Mako in c:\users\user\anaconda3\lib\site-packages (from alembic<2.0.0,>=1.8.1->trulens-core<2.0.0,>=1.0.0->trulens-eval) (1.2.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (8.27.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (1.0.0)
# Requirement already satisfied: notebook in c:\users\user\anaconda3\lib\site-packages (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (7.2.2)
# Requirement already satisfied: qtconsole in c:\users\user\anaconda3\lib\site-packages (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (5.5.1)
# Requirement already satisfied: jupyter-console in c:\users\user\anaconda3\lib\site-packages (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\user\anaconda3\lib\site-packages (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\user\anaconda3\lib\site-packages (from jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (6.28.0)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from munch<3.0,>=2.5->trulens-core<2.0.0,>=1.0.0->trulens-eval) (1.16.0)
# Requirement already satisfied: click in c:\users\user\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.9.1->trulens-feedback<2.0.0,>=1.0.0->trulens-eval) (8.1.7)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.9.1->trulens-feedback<2.0.0,>=1.0.0->trulens-eval) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.9.1->trulens-feedback<2.0.0,>=1.0.0->trulens-eval) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (from nltk<4.0.0,>=3.9.1->trulens-feedback<2.0.0,>=1.0.0->trulens-eval) (4.66.5)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\user\desktop\llm\.venv\lib\site-packages (from opentelemetry-api<2.0.0,>=1.0.0->trulens-core<2.0.0,>=1.0.0->trulens-eval) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\user\anaconda3\lib\site-packages (from opentelemetry-api<2.0.0,>=1.0.0->trulens-core<2.0.0,>=1.0.0->trulens-eval) (7.0.1)
# Collecting protobuf<6.0,>=5.0 (from opentelemetry-proto<2.0.0,>=1.0.0->trulens-core<2.0.0,>=1.0.0->trulens-eval)
#   Using cached protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Collecting opentelemetry-semantic-conventions==0.50b0 (from opentelemetry-sdk<2.0.0,>=1.0.0->trulens-core<2.0.0,>=1.0.0->trulens-eval)
#   Using cached opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.0.0->trulens-core<2.0.0,>=1.0.0->trulens-eval) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.0.0->trulens-core<2.0.0,>=1.0.0->trulens-eval) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.0.0->trulens-core<2.0.0,>=1.0.0->trulens-eval) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from plotly<6.0.0,>=5.22.0->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (8.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.4.2->trulens-core<2.0.0,>=1.0.0->trulens-eval) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.4.2->trulens-core<2.0.0,>=1.0.0->trulens-eval) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.31->trulens-core<2.0.0,>=1.0.0->trulens-eval) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.31->trulens-core<2.0.0,>=1.0.0->trulens-eval) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.31->trulens-core<2.0.0,>=1.0.0->trulens-eval) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0,>=2.31->trulens-core<2.0.0,>=1.0.0->trulens-eval) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\anaconda3\lib\site-packages (from rich<14.0,>=13.6->trulens-core<2.0.0,>=1.0.0->trulens-eval) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from rich<14.0,>=13.6->trulens-core<2.0.0,>=1.0.0->trulens-eval) (2.15.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn<2.0.0,>=1.3.0->trulens-feedback<2.0.0,>=1.0.0->trulens-eval) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy<3.0,>=2.0->trulens-core<2.0.0,>=1.0.0->trulens-eval) (3.0.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (5.3.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (10.4.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\user\anaconda3\lib\site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (16.1.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\user\anaconda3\lib\site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\user\anaconda3\lib\site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\user\anaconda3\lib\site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\user\anaconda3\lib\site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\user\anaconda3\lib\site-packages (from streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\user\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (4.23.0)
# Requirement already satisfied: toolz in c:\users\user\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.12.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from click->nltk<4.0.0,>=3.9.1->trulens-feedback<2.0.0,>=1.0.0->trulens-eval) (0.4.6)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\user\anaconda3\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api<2.0.0,>=1.0.0->trulens-core<2.0.0,>=1.0.0->trulens-eval) (1.14.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (4.0.7)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api<2.0.0,>=1.0.0->trulens-core<2.0.0,>=1.0.0->trulens-eval) (3.17.0)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\user\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (3.0.43)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.2.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0,>=13.6->trulens-core<2.0.0,>=1.0.0->trulens-eval) (0.1.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\user\anaconda3\lib\site-packages (from notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (5.7.2)
# Requirement already satisfied: pyzmq>=24 in c:\users\user\anaconda3\lib\site-packages (from ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (25.1.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\user\anaconda3\lib\site-packages (from Mako->alembic<2.0.0,>=1.8.1->trulens-core<2.0.0,>=1.0.0->trulens-eval) (2.1.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\user\anaconda3\lib\site-packages (from nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (1.2.1)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\user\anaconda3\lib\site-packages (from qtconsole->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\user\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.5.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\user\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (4.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\user\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\user\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2.0,>=1.35->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\user\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (305.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\user\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2.2.0)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (75.1.0)
# Requirement already satisfied: babel>=2.10 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\user\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.9.6)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\user\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2.5)
# Requirement already satisfied: executing in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.1.2->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (21.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.14.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\user\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (0.1.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\user\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\user\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter<2,>=1->trulens-dashboard<2.0.0,>=1.0.0->trulens-eval) (1.2.3)
# Downloading trulens_eval-1.3.3-py3-none-any.whl (37 kB)
# Downloading trulens_core-1.3.3-py3-none-any.whl (246 kB)
# Downloading trulens_dashboard-1.3.3-py3-none-any.whl (603 kB)
#    ---------------------------------------- 0.0/603.4 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/603.4 kB ? eta -:--:--
#    ---------------------------------- ----- 524.3/603.4 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 603.4/603.4 kB 1.3 MB/s eta 0:00:00
# Downloading trulens_feedback-1.3.3-py3-none-any.whl (47 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Using cached opentelemetry_api-1.29.0-py3-none-any.whl (64 kB)
# Using cached opentelemetry_proto-1.29.0-py3-none-any.whl (55 kB)
# Using cached opentelemetry_sdk-1.29.0-py3-none-any.whl (118 kB)
# Using cached opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl (166 kB)
# Downloading trulens_otel_semconv-1.3.3-py3-none-any.whl (5.5 kB)
# Using cached protobuf-5.29.3-cp310-abi3-win_amd64.whl (434 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, protobuf, munch, importlib-resources, fqdn, opentelemetry-proto, opentelemetry-api, opentelemetry-semantic-conventions, isoduration, trulens-otel-semconv, opentelemetry-sdk, trulens-core, trulens-feedback, trulens-dashboard, trulens-eval
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Not uninstalling protobuf at c:\users\user\anaconda3\lib\site-packages, outside environment C:\Users\User\Desktop\LLM\.venv
#     Can't uninstall 'protobuf'. No files were found to uninstall.
# Successfully installed fqdn-1.5.1 importlib-resources-6.5.2 isoduration-20.11.0 munch-2.5.0 opentelemetry-api-1.29.0 opentelemetry-proto-1.29.0 opentelemetry-sdk-1.29.0 opentelemetry-semantic-conventions-0.50b0 protobuf-5.29.3 trulens-core-1.3.3 trulens-dashboard-1.3.3 trulens-eval-1.3.3 trulens-feedback-1.3.3 trulens-otel-semconv-1.3.3 uri-template-1.3.0 webcolors-24.11.1

# %%
# !pip install trulens-eval==0.19.2 pandas nest-asyncio
# Out:
# ERROR: Could not find a version that satisfies the requirement trulens-eval==0.19.2 (from versions: 0.0.1a0, 0.0.1, 0.1.1a0, 0.1.1, 0.1.2a0, 0.1.2, 0.2.0a0, 0.2.0, 0.2.1a0, 0.2.1, 0.2.2a0, 0.2.2b0, 0.2.2, 0.3.0a0, 0.3.0b0, 0.3.0rc0, 0.3.0, 0.4.0a0, 0.4.0, 0.4.1a0, 0.4.1b0, 0.5.0a0, 0.5.0, 0.6.0a0, 0.6.0, 0.7.0a0, 0.7.0, 0.8.0a0, 0.8.0, 0.9.0a0, 0.9.0, 0.10.0, 0.11.0a0, 0.11.0b0, 0.11.0, 0.12.0a0, 0.12.0, 0.13.0a0, 0.13.0, 0.14.0a0, 0.14.0b0, 0.14.0, 0.27.0, 0.27.1, 0.27.2, 0.28.0, 0.28.1, 0.28.2, 0.29.0, 0.30.0, 0.30.1, 0.31.0, 0.31.1, 0.32.0, 0.32.1, 0.33.0, 0.33.1, 1.0.1a1, 1.0.1a4, 1.0.1a5, 1.0.1a6, 1.0.1, 1.0.2, 1.0.3, 1.0.4, 1.0.5, 1.0.6, 1.0.7, 1.0.8, 1.0.9, 1.0.10, 1.0.11, 1.1.0a0, 1.1.0a1, 1.1.0a2, 1.1.0a3, 1.1.0a4, 1.1.0, 1.2.0, 1.2.1, 1.2.2, 1.2.3, 1.2.4, 1.2.5, 1.2.6, 1.2.7, 1.2.8, 1.2.9, 1.2.10, 1.2.11, 1.3.0, 1.3.1, 1.3.2, 1.3.3a0, 1.3.3)
# ERROR: No matching distribution found for trulens-eval==0.19.2
